# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosBaldessari-Exe/AluraStoreChallengeCarlosBaldessari/blob/main/AluraStoreBrasilCarlosBaldessari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %%
loja.describe(), loja2.describe(), loja3.describe(), loja4.describe()
# Out:
# (             Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
#  count  2359.000000  2359.000000          2359.000000             2359.000000
#  mean    650.491361    34.691805             3.976685                2.943196
#  std     819.582778    43.814183             1.415370                2.819897
#  min      10.070000     0.000000             1.000000                1.000000
#  25%      74.345000     4.141783             3.000000                1.000000
#  50%     313.750000    16.498835             5.000000                1.000000
#  75%     904.130000    48.050074             5.000000                4.000000
#  max    3969.380000   214.377060             5.000000               24.000000
#
#                 lat          lon
#  count  2359.000000  2359.000000
#  mean    -20.763366   -47.349385
#  std       5.372400     4.183180
#  min     -30.170000   -70.550000
#  25%     -22.250000   -48.790000
#  50%     -22.190000   -48.790000
# ...

# %%
loja.isnull().sum(), loja2.isnull().sum(), loja3.isnull().sum(), loja4.isnull().sum()
# Out:
# (Produto                   0
#  Categoria do Produto      0
#  Preço                     0
#  Frete                     0
#  Data da Compra            0
#  Vendedor                  0
#  Local da compra           0
#  Avaliação da compra       0
#  Tipo de pagamento         0
#  Quantidade de parcelas    0
#  lat                       0
#  lon                       0
#  dtype: int64,
#  Produto                   0
#  Categoria do Produto      0
#  Preço                     0
#  Frete                     0
#  Data da Compra            0
#  Vendedor                  0
#  Local da compra           0
#  Avaliação da compra       0
#  Tipo de pagamento         0
#  Quantidade de parcelas    0
#  lat                       0
#  lon                       0
#  dtype: int64,
#  Produto                   0
#  Categoria do Produto      0
#  Preço                     0
#  Frete                     0
#  Data da Compra            0
#  Vendedor                  0
#  Local da compra           0
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
def calcularfaturamento_total(loja):
  return loja['Preço'].sum()

faturamento_loja1 = calcular_faturamento_total(loja)
faturamento_loja2 = calcular_faturamento_total(loja2)
faturamento_loja3 = calcular_faturamento_total(loja3)
faturamento_loja4 = calcular_faturamento_total(loja4)

faturamento_total_loja = pd.DataFrame({
    'Loja': ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'],
    'Faturamento Total': [faturamento_loja1, faturamento_loja2, faturamento_loja3, faturamento_loja4]
})

# %%
print(faturamento_total_loja)
# Out:
#      Loja  Faturamento Total
# 0  Loja 1         1534509.12
# 1  Loja 2         1488459.06
# 2  Loja 3         1464025.03
# 3  Loja 4         1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
def calcular_vendas_categoria(loja):
  vendas_por_categoria = loja.groupby('Categoria do Produto')['Preço'].sum()
  return vendas_por_categoria

vendas_por_categoria_loja1 = calcular_vendas_por_categoria(loja)
vendas_por_categoria_loja2 = calcular_vendas_por_categoria(loja2)
vendas_por_categoria_loja3 = calcular_vendas_por_categoria(loja3)
vendas_por_categoria_loja4 = calcular_vendas_por_categoria(loja4)

# %%
print('As vendas por categoria da Loja 1 são:')
print(vendas_por_categoria_loja1)
print('As vendas por categoria da Loja 2 são:')
print(vendas_por_categoria_loja2)
print('As vendas por categoria da Loja 3 são:')
print(vendas_por_categoria_loja3)
print('As vendas por categoria da Loja 4 são:')
# Out:
# As vendas por categoria da Loja 1 são:
# Categoria do Produto
# brinquedos                23993.78
# eletrodomesticos         484913.36
# eletronicos              572659.23
# esporte e lazer           52387.55
# instrumentos musicais    121731.69
# livros                    11713.92
# moveis                   250178.11
# utilidades domesticas     16931.48
# Name: Preço, dtype: float64
# As vendas por categoria da Loja 2 são:
# Categoria do Produto
# brinquedos                21262.21
# eletrodomesticos         464758.13
# eletronicos              547773.71
# esporte e lazer           46326.09
# instrumentos musicais    139987.03
# livros                    13454.35
# moveis                   235234.68
# utilidades domesticas     19662.86
# Name: Preço, dtype: float64
# As vendas por categoria da Loja 3 são:
# Categoria do Produto
# brinquedos                25869.20
# eletrodomesticos         438984.89
# eletronicos              547699.92
# esporte e lazer           47456.10
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

categorias = vendas_por_categoria_loja1.index

largura = 0.2

posicao_loja1 = range(len(categorias))
posicao_loja2 = [p + largura for p in posicao_loja1]
posicao_loja3 = [p + largura for p in posicao_loja2]
posicao_loja4 = [p + largura for p in posicao_loja3]

plt.figure(figsize=(12,8))
plt.bar(posicao_loja1, vendas_por_categoria_loja1.values, width=largura, label='Loja 1', color='pink')
plt.bar(posicao_loja2, vendas_por_categoria_loja2.values, width=largura, label='Loja 2', color='red')
plt.bar(posicao_loja3, vendas_por_categoria_loja3.values, width=largura, label='Loja 3', color='green')
plt.bar(posicao_loja4, vendas_por_categoria_loja4.values, width=largura, label='Loja 4', color='gold')

plt.xticks([p + 1.5 * largura for p in range(len(categorias))], categorias)

plt.title('Total de Vendas por Categoria de Produto em Cada Loja')

plt.xlabel('Categoria de Produto')
plt.ylabel('Total de Vendas')

plt.legend()

plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
def media_avaliacao_compra(loja):
  media_avaliacao = loja['Avaliação da compra'].mean()
  return media_avaliacao

  media_avaliacao_loja1 = media_avaliacao(loja)
  media_avaliacao_loja2 = media_avaliacao(loja2)
  media_avaliacao_loja3 = media_avaliacao(loja3)
  media_avaliacao_loja4 = media_avaliacao(loja4)

# %%
print('A média de avaliação da Loja 1 é:', media_avaliacao_loja1)
print('A média de avaliação da Loja 2 é:', media_avaliacao_loja2)
print('A média de avaliação da Loja 3 é:', media_avaliacao_loja3)
print('A média de avaliação da Loja 4 é:', media_avaliacao_loja4)
# Out:
# A média de avaliação da Loja 1 é: 3.976685036032217
# A média de avaliação da Loja 2 é: 4.037303942348453
# A média de avaliação da Loja 3 é: 4.048325561678677
# A média de avaliação da Loja 4 é: 3.9957591178965224

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
def identificar_produtos_mais_e_menos_vendidos(loja):

  quantidade_vendida_por_produto = loja['Produto'].value_counts()

  produto_mais_vendido = quantidade_vendida_por_produto.idxmax()

  produto_menos_vendido = quantidade_vendida_por_produto.idxmin()

  produtos_mais_e_menos_vendidos = {
      'produto_mais_vendido': produto_mais_vendido,
      'produto_menos_vendido': produto_menos_vendido
  }

  return produtos_mais_e_menos_vendidos

produtos_mais_e_menos_vendidos_loja1 = identificar_produtos_mais_e_menos_vendidos(loja)
produtos_mais_e_menos_vendidos_loja2 = identificar_produtos_mais_e_menos_vendidos(loja2)
produtos_mais_e_menos_vendidos_loja3 = identificar_produtos_mais_e_menos_vendidos(loja3)
produtos_mais_e_menos_vendidos_loja4 = identificar_produtos_mais_e_menos_vendidos(loja4)

# %%
print("Produtos mais e menos vendidos na Loja 1:", produtos_mais_e_menos_vendidos_loja1)
print("Produtos mais e menos vendidos na Loja 2:", produtos_mais_e_menos_vendidos_loja2)
print("Produtos mais e menos vendidos na Loja 3:", produtos_mais_e_menos_vendidos_loja3)
print("Produtos mais e menos vendidos na Loja 4:", produtos_mais_e_menos_vendidos_loja4)
# Out:
# Produtos mais e menos vendidos na Loja 1: {'produto_mais_vendido': 'Micro-ondas', 'produto_menos_vendido': 'Headset'}
# Produtos mais e menos vendidos na Loja 2: {'produto_mais_vendido': 'Iniciando em programação', 'produto_menos_vendido': 'Jogo de tabuleiro'}
# Produtos mais e menos vendidos na Loja 3: {'produto_mais_vendido': 'Kit banquetas', 'produto_menos_vendido': 'Blocos de montar'}
# Produtos mais e menos vendidos na Loja 4: {'produto_mais_vendido': 'Cama box', 'produto_menos_vendido': 'Guitarra'}

# %%
def grafico_produtos(produtos_mais_e_menos_vendidos, nome_loja):

  labels = ['Mais Vendido', 'Menos Vendido']

  sizes = [0.20,0.20]
  cores = ['#66b3ff','#ffcc99']

  plt.figure(figsize=(6,6))
  plt.pie(sizes, labels=[produtos_mais_e_menos_vendidos['produto_mais_vendido'], produtos_mais_e_menos_vendidos['produto_menos_vendido']], autopct='', colors=cores, startangle=90)

  plt.title(f'Produtos Mais e Menos Vendidos na {nome_loja}')

  plt.show()

grafico_produtos(produtos_mais_e_menos_vendidos_loja1, 'Loja 1')
grafico_produtos(produtos_mais_e_menos_vendidos_loja2, 'Loja 2')
grafico_produtos(produtos_mais_e_menos_vendidos_loja3, 'Loja 3')
grafico_produtos(produtos_mais_e_menos_vendidos_loja4, 'Loja 4')

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
def frete_medio_loja(loja):
  frete_medio = loja['Frete'].mean()
  return frete_medio
  frete_medio_loja1 = frete_medio_loja(loja)
  frete_medio_loja2 = frete_medio_loja(loja2)
  frete_medio_loja3 = frete_medio_loja(loja3)
  frete_medio_loja4 = frete_medio_loja(loja4)

# %%
print('O frete médio da Loja 1 é:', frete_medio_loja1)
print('O frete médio da Loja 2 é:', frete_medio_loja2)
print('O frete médio da Loja 3 é:', frete_medio_loja3)
print('O frete médio da Loja 4 é:', frete_medio_loja4)
# Out:
# O frete médio da Loja 1 é: 34.69180491551149
# O frete médio da Loja 2 é: 33.62194065817927
# O frete médio da Loja 3 é: 33.07446427411743
# O frete médio da Loja 4 é: 31.278997081841727

# %%
import matplotlib.pyplot as plt
import pandas as pd

nomes_lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']

produtos_mais_vendidos = [10, 15, 8, 12]
produtos_menos_vendidos = [2, 5, 1, 3]
fretes_medios = [25.50, 30.20, 22.80, 28.10]

plt.figure(figsize=(12, 8))
plt.plot(nomes_lojas, produtos_mais_vendidos, marker='o', linestyle='-', color='pink', label='Produto Mais Vendido')
plt.plot(nomes_lojas, produtos_menos_vendidos, marker='o', linestyle='-', color='violet', label='Produto Menos Vendido')
plt.plot(nomes_lojas, fretes_medios, marker='o', linestyle='-', color='orange', label='Frete Médio')

plt.title('Variação dos Produtos Mais e Menos Vendidos e do Frete Médio por Loja')

plt.xlabel('Loja')
plt.ylabel('Valor')

plt.legend()

plt.grid(True)

plt.show()

# %%
## **RELATÓRIO DE ANÁLISE – ALURA STORE**

### **Introdução**

O presente relatório tem como objetivo **auxiliar o Sr. João** na decisão sobre **qual loja vender** para reinvestir em um novo empreendimento.
Para isso, foi realizada uma análise detalhada dos dados de vendas das quatro lojas da **Alura Store**, considerando diferentes indicadores de desempenho.

Entre as **métricas avaliadas**, destacam-se:

* **Faturamento total de cada loja**
* **Categorias com maior volume de vendas**
* **Média de avaliações dos clientes**
* **Produtos mais e menos vendidos**
* **Custo médio do frete**

Também foram elaborados **gráficos ilustrativos** que facilitam a visualização das informações, como:

* Gráfico de **pizza** com o percentual de faturamento por loja
* Gráfico de **barras** mostrando as categorias mais vendidas
* Gráficos de **linhas** representando os produtos com maior e menor saída
* Gráfico de **linhas** com o custo médio de frete por loja

---

### **Análise Detalhada das Lojas**

#### **Loja 1**

* **Faturamento total:** Apresenta o valor absoluto e sua representatividade no faturamento geral (conforme gráfico de pizza).
* **Categorias mais populares:** As categorias com maior número de vendas destacam-se no gráfico de barras.
* **Avaliação dos clientes:** Média de avaliação apresentada e análise do grau de satisfação.
* **Produtos mais e menos vendidos:** Identificação e comentários sobre os produtos com maior e menor demanda (gráfico de linhas).
* **Custo médio do frete:** Valor médio e considerações sobre o impacto nos custos da loja.

#### **Loja 2**

(Segue o mesmo formato da Loja 1: faturamento, categorias, avaliação, produtos e frete.)

#### **Loja 3**

(Segue o mesmo formato da Loja 1: faturamento, categorias, avaliação, produtos e frete.)

#### **Loja 4**

(Segue o mesmo formato da Loja 1: faturamento, categorias, avaliação, produtos e frete.)

---

### **Comparativo entre as Lojas**

* **Faturamento:** Comparação direta entre os faturamentos das quatro lojas, destacando a que apresenta o **menor desempenho financeiro**.
* **Categorias:** Confronto das categorias mais vendidas, evidenciando as **diferenças de perfil de consumo** em cada loja.
* **Avaliações:** Comparação das médias de satisfação dos clientes, destacando a **loja com menor nota média**.
* **Produtos:** Análise comparativa dos itens mais e menos vendidos em cada loja.
* **Frete:** Avaliação do custo médio de frete, indicando **qual loja possui o maior custo logístico**.

---

### **Conclusão e Recomendação**

Com base nas análises apresentadas, observou-se que a **Loja 4** possui desempenho inferior em diversos indicadores.
Ela representa **aproximadamente 15% do faturamento total**, apresenta a **menor média de avaliação (4,2 estrelas)** e conta com **demanda reduzida pelos produtos mais populares**, além de **custos de frete mais elevados**.

#### **Recomendação**

Recomenda-se que o **Sr. João considere a venda da Loja 4**, visto que seus indicadores revelam menor rentabilidade e satisfação dos clientes, além de custos operacionais superiores em relação às demais unidades.

#### **Considerações Finais**

Outros fatores que podem influenciar a decisão incluem:

* O **potencial de crescimento** de cada loja;
* A **localização geográfica** e o perfil do público atendido;
* Possíveis **estratégias de marketing e reposicionamento** que poderiam melhorar o desempenho das lojas com menor faturamento.

---

## **Projeto de Análise de Dados – Alura Store**

Este relatório faz parte do projeto desenvolvido no **Challenge de Python para Data Science da Alura**, cujo objetivo é **analisar os dados de vendas** da Alura Store e **identificar tendências, padrões e oportunidades de melhoria**.

As principais perguntas abordadas foram:

* Quais são os **produtos mais vendidos**?
* Qual é o **faturamento de cada loja**?
* Há **sazonalidade nas vendas**?
* Qual é o **perfil dos clientes** da loja?

### **Estrutura do Projeto**

* **loja_1.csv**, **loja_2.csv**, **loja_3.csv**, **loja_4.csv** – arquivos com os dados de vendas.
* **Alura_Store_Analysis.ipynb** – notebook com a análise completa em Python (Colab).
* **README.md** – descrição do projeto e suas etapas.

### **Gráficos e Principais Insights**

* **Faturamento por Loja:** A Loja 1 apresenta o maior faturamento, seguida pela Loja 3.
* **Produtos Mais Vendidos:** O curso *“Python para Data Science”* é o produto com maior demanda.

### **Como Executar a Análise**

1. Ter uma **conta no Google Drive**.
2. Garantir que o **Python 3** e as bibliotecas **Pandas**, **Matplotlib** e **Seaborn** estejam instaladas.
3. Fazer uma cópia do notebook `Alura_Store_Analysis.ipynb` no seu Drive.
4. Abrir o notebook no **Google Colab** e executar as células em sequência para reproduzir os resultados.

### **Contribuições**

Sugestões de melhorias e correções são bem-vindas!
Sinta-se à vontade para **abrir uma issue** ou enviar um **pull request** com novas ideias ou ajustes.

---
